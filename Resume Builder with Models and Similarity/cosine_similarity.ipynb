# %%
resume={"resume_storage": {
        "20260219155116160694": {
          "created_at": "2026-02-19T15:51:16.160694",
          "education": [
            {
              "degree": "Bachelor of Science in Information Technology",
              "school": "Bulacan State University",
              "location": "Malolos, Bulacan, Philippines",
              "year": "2024",
              "info": "Dean’s Lister (2022-2023)\nRelevant Coursework: Data Structures, Database Management, Machine Learning, Software Engineering"
            }
          ],
          "experiences": [
            {
              "title": "Junior Data Analyst Intern",
              "company": "TechSolutions Inc.",
              "location": "Quezon City, Philippines",
              "startDate": "June 2023",
              "endDate": "August 2023",
              "description": "Analyzed sales and customer datasets using Python and Excel.\nCreated dashboards in Power BI for performance tracking.\nPerformed data cleaning and preprocessing using Pandas."
            },
            {
              "title": "Freelance Python Developer",
              "company": "Self-Employed",
              "location": "Remote",
              "startDate": "January 2022",
              "endDate": "Present",
              "description": "Developed automation scripts for Excel and CSV processing.\nBuilt small data transformation pipelines using Pandas.\nOptimized data workflows for faster processing."
            }
          ],
          "personal_info": {
            "first_name": "Audrie Lex",
            "last_name": "Afundar",
            "address": "Blk 17 Lot 47, Sarmiento Homes, Muzon",
            "city": "San Jose Del Monte, Bulacan",
            "country": "Philippines",
            "email": "audrielex.l.afundar@gmail.com",
            "phone": "+63-922-322-5905"
          },
          "skills": {
            "technical": "Python\nPandas\nNumPy\nSQL\nPower BI\nExcel\nData Cleaning\nData Visualization\nMachine Learning Basics",
            "soft": "Analytical Thinking\nProblem Solving\nCommunication\nTime Management\nAttention to Detail",
            "interests": "Data Science\nArtificial Intelligence\nBusiness Analytics\nAutomation\nOpen Source Projects"
          },
          "resume_id": "20260219155116160694",
          "updated_at": "2026-02-19T15:56:02.697486"
        }
      }
    }

# %%
resume_1={
  "resume_storage": {
    "RESUME_001": {
      "education": [
        {
          "degree": "Bachelor of Science in Statistics",
          "school": "University of the Philippines",
          "location": "Diliman, Philippines",
          "year": "2023",
          "info": "Relevant Coursework: Probability, Regression Analysis, Data Mining"
        }
      ],
      "experiences": [
        {
          "title": "Data Analyst",
          "company": "Metro Retail Corp",
          "location": "Manila, Philippines",
          "startDate": "2023",
          "endDate": "Present",
          "description": "Analyzed sales data using Python and SQL. Built Power BI dashboards. Performed data cleaning and statistical analysis."
        }
      ],
      "skills": {
        "technical": "Python Pandas NumPy SQL Power BI Excel Data Cleaning Statistics Machine Learning",
        "soft": "Analytical Thinking Communication Problem Solving Attention to Detail",
        "interests": "Data Science Business Intelligence Artificial Intelligence"
      }
    }
  }
}

# %%
resume_2={
  "resume_storage": {
    "RESUME_002": {
      "education": [
        {
          "degree": "Bachelor of Science in Computer Science",
          "school": "Ateneo de Manila University",
          "location": "Quezon City, Philippines",
          "year": "2022",
          "info": "Specialized in Software Engineering"
        }
      ],
      "experiences": [
        {
          "title": "Backend Developer",
          "company": "FinTech Solutions",
          "location": "Taguig, Philippines",
          "startDate": "2022",
          "endDate": "Present",
          "description": "Developed REST APIs using Python and Django. Managed PostgreSQL databases and optimized queries."
        }
      ],
      "skills": {
        "technical": "Python Django PostgreSQL SQL APIs Git Docker",
        "soft": "Problem Solving Teamwork Communication",
        "interests": "System Architecture Cloud Computing"
      }
    }
  }
}

# %%
resume_3={
  "resume_storage": {
    "RESUME_004": {
      "education": [
        {
          "degree": "Bachelor of Fine Arts in Multimedia Arts",
          "school": "University of Santo Tomas",
          "location": "Manila, Philippines",
          "year": "2021",
          "info": "Specialized in Visual Design"
        }
      ],
      "experiences": [
        {
          "title": "Graphic Designer",
          "company": "Creative Studio PH",
          "location": "Makati, Philippines",
          "startDate": "2021",
          "endDate": "Present",
          "description": "Designed marketing materials and branding assets using Adobe Photoshop and Illustrator."
        }
      ],
      "skills": {
        "technical": "Photoshop Illustrator Figma Video Editing Branding",
        "soft": "Creativity Communication Collaboration",
        "interests": "Digital Art Photography Animation"
      }
    }
  }
}

# %%
resume_4={
  "resume_storage": {
    "RESUME_005": {
      "education": [
        {
          "degree": "Master of Science in Data Science",
          "school": "Mapúa University",
          "location": "Manila, Philippines",
          "year": "2024",
          "info": "Thesis in Predictive Modeling"
        }
      ],
      "experiences": [
        {
          "title": "Data Scientist",
          "company": "AI Solutions PH",
          "location": "Manila, Philippines",
          "startDate": "2023",
          "endDate": "Present",
          "description": "Built machine learning models using Python and Scikit-learn. Performed feature engineering and statistical analysis. Developed dashboards for business insights."
        }
      ],
      "skills": {
        "technical": "Python Pandas NumPy SQL Machine Learning Statistics Data Visualization Power BI",
        "soft": "Analytical Thinking Critical Thinking Communication",
        "interests": "Artificial Intelligence Big Data Predictive Analytics"
      }
    }
  }
}

# %%
job_desc={
      "job_posting": {
        "job_id": "DATA_ANALYST_001",
        "created_at": "2026-02-19T16:10:00.000000",
        "job_title": "Data Analyst",
        "company": "Insight Analytics Corp",
        "location": "Manila, Philippines",
        "employment_type": "Full-Time",
        "job_description": "We are seeking a detail-oriented and analytical Data Analyst to collect, process, and analyze structured and unstructured datasets to support business decision-making. The candidate will be responsible for data cleaning, statistical analysis, dashboard creation, reporting insights, and automating reporting workflows.",
        "responsibilities": [
          "Collect and clean structured and unstructured data",
          "Analyze datasets using Python and SQL",
          "Build dashboards using Power BI or Tableau",
          "Perform exploratory data analysis (EDA)",
          "Present insights to stakeholders",
          "Automate recurring reports"
        ],
        "required_skills": {
          "technical": [
            "Python",
            "Pandas",
            "NumPy",
            "SQL",
            "Power BI",
            "Excel",
            "Data Cleaning",
            "Data Visualization",
            "Basic Statistics",
            "Machine Learning Fundamentals"
          ],
          "soft": [
            "Analytical Thinking",
            "Attention to Detail",
            "Problem Solving",
            "Communication Skills",
            "Time Management"
          ]
        },
        "experience_required": "1-3 years in data analysis or related field",
        "education_required": "Bachelor’s degree in Information Technology, Computer Science, Statistics, or related field"
      }
    }

# %%
resume_list = [resume, resume_1, resume_2, resume_3,resume_4]

# %%
import re

def clean_text(text):
    if not text:
        return ""
    
    text = text.replace("\n", " ").replace("\r", " ")
    
    text = re.sub(r"\s+", " ", text)
    
    return text.strip()


def flatten_resume(resume_json):
    resume = list(resume_json["resume_storage"].values())[0]
    
    sections = []
    
    # Education
    for edu in resume.get("education", []):
        edu_text = f"{edu.get('degree', '')} from {edu.get('school', '')}. {edu.get('info', '')}"
        sections.append(clean_text(edu_text))
    
    # Experience
    for exp in resume.get("experiences", []):
        exp_text = f"{exp.get('title', '')} at {exp.get('company', '')}. {exp.get('description', '')}"
        sections.append(clean_text(exp_text))
    
    # Skills
    skills = resume.get("skills", {})
    
    technical = clean_text(skills.get("technical", ""))
    soft = clean_text(skills.get("soft", ""))
    interests = clean_text(skills.get("interests", ""))
    
    sections.append(f"Technical Skills: {technical}")
    sections.append(f"Soft Skills: {soft}")
    sections.append(f"Interests: {interests}")
    
    final_text = " ".join(sections)
    final_text = clean_text(final_text)
    
    return final_text




def flatten_job(job_json):
    job = job_json["job_posting"]
    
    sections = []
    
    sections.append(job.get("job_title", ""))
    sections.append(job.get("job_description", ""))
    
    responsibilities = job.get("responsibilities", [])
    sections.append("Responsibilities: " + " ".join(responsibilities))
    
    technical = job.get("required_skills", {}).get("technical", [])
    soft = job.get("required_skills", {}).get("soft", [])
    
    sections.append("Technical Skills Required: " + " ".join(technical))
    sections.append("Soft Skills Required: " + " ".join(soft))
    
    return " ".join(sections)

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Cosine Similarity (Embeddings): 0.75207806

# %%
resume_text_lists=[]
job_text = flatten_job(job_desc)

job_embedding = model.encode(job_text)
for i, resume in enumerate(resume_list):
    resume_text=flatten_resume(resume)
    resume_embedding = model.encode(resume_text)
    similarity_score = cosine_similarity(
        [resume_embedding],
        [job_embedding]
    )

    score = similarity_score[0][0]
    
    print(f"Resume {i+1} Similarity: {score:.4f}")
# Out:
# Resume 1 Similarity: 0.7521
# Resume 2 Similarity: 0.7038
# Resume 3 Similarity: 0.4134
# Resume 4 Similarity: 0.2319
# Resume 5 Similarity: 0.7079
